# %%
# import qrcode
# import qrcode.image.svg

# url = "https://srisathyasaibabacenterofconcord.github.io/SSSBCC-Website/"

# # Create SVG QR code
# factory = qrcode.image.svg.SvgImage
# qr = qrcode.QRCode(error_correction=qrcode.constants.ERROR_CORRECT_H)
# qr.add_data(url)
# qr.make(fit=True)
# img = qr.make_image(image_factory=factory)

# img.save("SSSBCC_QR.svg")
# print("Vector QR code saved as SSSBCC_QR.svg")
import qrcode

url = "https://srisathyasaibabacenterofconcord.github.io/SSSBCC-Website/"

qr = qrcode.QRCode(
    version=1,
    error_correction=qrcode.constants.ERROR_CORRECT_H,
    box_size=40,  # bigger box = higher resolution
    border=4
)
qr.add_data(url)
qr.make(fit=True)

img = qr.make_image(fill_color="black", back_color="white")
img.save("SSSBCC_QR_highres.png")
